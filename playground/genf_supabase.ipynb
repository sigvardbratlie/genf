# %%
from supabase import create_client, Client

# %%
SUPABASE_ANON_KEY="sb_publishable__3c0gbsapSO7Tgb4_HNmjw_IgDHhbdv"
SUPABASE_URL="https://eijvsbccseknvngvlfmd.supabase.co"

# %%
client = create_client(SUPABASE_URL, SUPABASE_ANON_KEY)

# %%
client.table("buk_cash").select("*").execute()
# Out:
# APIResponse(data=[{'id': 'abba7e51-6bc1-401b-997d-b727e64e0aa2', 'created_at': '2026-02-04T07:56:56.279847+00:00', 'custom_id': None, 'email': 'vebjorn.risa2@gmail.com', 'role': 'admin', 'first_name': 'ZDeveloper', 'last_name': 'Admin', 'bank_account_number': None, 'date_of_birth': '2000-07-17T00:00:00+00:00'}, {'id': '2655170d-6cac-4d40-bf21-25925320ba54', 'created_at': '2026-02-04T07:56:56.279847+00:00', 'custom_id': None, 'email': 'tim_baltz@hotmail.no', 'role': 'admin', 'first_name': 'Tim', 'last_name': 'Baltzersen', 'bank_account_number': '12065804768', 'date_of_birth': '1999-06-21T00:00:00+00:00'}, {'id': '0f0500c2-5765-47cc-878b-833c1fb866e1', 'created_at': '2026-02-04T07:56:56.279847+00:00', 'custom_id': None, 'email': 'minahauk@gmail.com', 'role': 'admin', 'first_name': 'Mina', 'last_name': 'Bratlie', 'bank_account_number': '18136576816', 'date_of_birth': None}, {'id': '462e8c1d-fabd-43f0-bdae-d6888bbeef4f', 'created_at': '2026-02-04T07:56:56.279847+00:00', 'custom_id': None
# ...
