# %% [markdown]
# ## API - www.buk.cash

# %%
import os
from datetime import date, datetime, timedelta
from typing import Optional
import json
from api_complete_documentation import fetch_job_applications,fetch_work_requests
from test_api_all_functions import fetch_profiles

try:
    from supabase import create_client, Client
    from dotenv import load_dotenv
except ImportError:
    print("Error: Required packages not installed.")
    print("Please run: pip install supabase python-dotenv")

# Load environment variables from .env file if it exists
load_dotenv()
# Out:
# True

# %%
# Configuration - Update these or set as environment variables
# Project ID: qvkdyodpfauvpsamrmew
SUPABASE_URL = os.getenv("SUPABASE_URL", "https://qvkdyodpfauvpsamrmew.supabase.co")
SUPABASE_ANON_KEY = os.getenv("SUPABASE_ANON_KEY", "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InF2a2R5b2RwZmF1dnBzYW1ybWV3Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDkzNzMyMDEsImV4cCI6MjA2NDk0OTIwMX0.gMscCXj733-_cT87_ErXPHaaa3YQdWE5gjpJ8XZ4yXI")
API_KEY = os.getenv("API_KEY", "07c78e44a658705dfde241ba2cd239d9")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_ANON_KEY)

# %%
r = fetch_work_requests(supabase, API_KEY, )

# %%
r[0]
# Out:
# {'id': '199b73ef-6695-4e4a-8fad-890b0629a487',
#  'requester_id': '33bcdb1d-4c6f-4dfc-926d-b33136f4ce72',
#  'title': 'Utsalgsbod Søndag 25.01🔥☕️🪵',
#  'description': 'Utsalgsbod fra 17:30 (30 min før møte), frem til ca 20:30. ',
#  'location': 'Årvoldveien, 1529 Moss',
#  'payment_type': 'hourly',
#  'hourly_rate': None,
#  'fixed_fee': None,
#  'base_fee': None,
#  'estimated_hours': 3.0,
#  'desired_start_date': '2026-01-25',
#  'status': 'approved',
#  'is_priority': False,
#  'needs_coordinator': False,
#  'assigned_to': None,
#  'approved_by': '33bcdb1d-4c6f-4dfc-926d-b33136f4ce72',
#  'approved_at': '2026-01-19T21:31:34.732+00:00',
#  'created_at': '2026-01-19T21:30:31.585234+00:00',
#  'updated_at': '2026-01-19T21:35:41.005512+00:00',
#  'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#  'is_full': False,
#  'contact_person': 'Sigvard Bratlie (admin)',
#  'completed_at': None,
#  'estimated_u16_workers': 0,
#  'estimated_u18_workers': 2,
#  'estimated_o18_workers': 1,
#  'unit_name': None,
#  'unit_rate': None,
#  'contact_person_id': '462e8c1d-fabd-43f0-bdae-d6888bbeef4f'}

# %%
job = fetch_job_applications(supabase, API_KEY, "199b73ef-6695-4e4a-8fad-890b0629a487")
job
# Out:
# [{'id': 'b3047dc4-3d22-4f86-92d9-f9af039a0bf1',
#   'work_request_id': '199b73ef-6695-4e4a-8fad-890b0629a487',
#   'user_id': '125d01c2-2628-410e-927f-3fc6e028e687',
#   'created_at': '2026-01-19T21:43:23.651723+00:00',
#   'user_first_name': 'Mirella Stadven',
#   'user_last_name': 'Jaren',
#   'user_email': 'mirellastadven@gmail.com'},
#  {'id': '20bfc080-6b7b-4278-b270-c820784db154',
#   'work_request_id': '199b73ef-6695-4e4a-8fad-890b0629a487',
#   'user_id': 'a0e88e8c-a425-4565-b83a-5e51d583aa79',
#   'created_at': '2026-01-19T21:43:20.54292+00:00',
#   'user_first_name': 'Rianne Mercedes',
#   'user_last_name': 'Nagy',
#   'user_email': 'riannemercedes@gmail.com'}]

# %%
from datetime import datetime,date

# %%
str(datetime.today  ())
# Out:
# '2026-01-20 16:05:27.425263'

# %%
str(date.today())
# Out:
# '2026-01-20'
