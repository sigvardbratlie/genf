# %% [markdown]
# # Genf Workbench #

# %%
import re
from typing import Literal
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
import os
import logging
from google.cloud import bigquery
load_dotenv()
# Out:
# True

# %%
from supabase import create_client 
supabase = create_client(os.getenv("SUPABASE_URL"),os.getenv("SUPABASE_ANON_KEY"))

# %%
response = supabase.table("bcc_members").select("*").limit(10).execute()
response.data
# Out:
# [{'person_id': 42403,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Othilie Smith',
#   'last_name': 'Nielsen',
#   'display_name': 'Othilie Smith Nielsen',
#   'birthdate': '2007-04-05T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'othilienielsen@gmail.com',
#   'cellphone': '+47 47 62 60 15',
#   'address_line_1': 'Nilseskauveien 10',
#   'city': 'KRÅKSTAD',
#   'postal_code': '1408',
#   'mother_name': 'Elisabeth Smith Nielsen',
#   'father_name': 'Johan Riis Nielsen'},
#  {'person_id': 41647,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Michelle',
#   'last_name': 'Pfeifer',
#   'display_name': 'Michelle Helen Pfeifer',
#   'birthdate': '2007-04-23T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'pfeifer.mhp@gmail.com',
#   'cellphone': '+47 472 40 800',
#   'address_line_1': 'Glenneveien 4',
#   'city': 'KRÅKSTAD',
#   'postal_code': '1408',
#   'mother_name': 'Esther Pfeifer',
#   'father_name': 'Sigurd Pfeifer'},
#  {'person_id': 41629,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Eunike',
#   'last_name': 'Skare',
#   'display_name': 'Eunike Skare',
#   'birthdate': '2007-03-14T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'eunike.skare@gmail.com',
#   'cellphone': '+47 483 06 257',
#   'address_line_1': 'Solbakkveien 13',
#   'city': 'LANGHUS',
#   'postal_code': '1405',
#   'mother_name': 'Rebekka Steigmüller Skare',
#   'father_name': 'Per Sveinung Skare'},
#  {'person_id': 41617,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Ida Lin',
#   'last_name': 'Baumann',
#   'display_name': 'Ida Lin Baumann',
#   'birthdate': '2007-04-19T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'idalinbaum@icloud.com',
#   'cellphone': '+47 969 18 919',
#   'address_line_1': 'Berger Terrasse 10',
#   'city': 'NORDRE FROGN',
#   'postal_code': '1455',
#   'mother_name': 'Heidi Drageseth Baumann',
#   'father_name': 'Olav Baumann'},
#  {'person_id': 42250,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Savannah',
#   'last_name': 'Schmidt',
#   'display_name': 'Savannah Schmidt',
#   'birthdate': '2007-11-25T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'savannah.schmidt@icloud.com',
#   'cellphone': '+47 48 40 85 23',
#   'address_line_1': 'Gamle Kongevei 18',
#   'city': 'SKI',
#   'postal_code': '1423',
#   'mother_name': 'Silje Drageseth Schmidt',
#   'father_name': 'Ron Schmidt'},
#  {'person_id': 42053,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Elisabeth',
#   'last_name': 'Ødegård',
#   'display_name': 'Elisabeth Ødegård',
#   'birthdate': '2007-10-08T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'elisabethodegard001@gmail.com',
#   'cellphone': '+47 923 56 711',
#   'address_line_1': 'Sneisveien 26',
#   'city': 'VINTERBRO',
#   'postal_code': '1407',
#   'mother_name': 'Anita Ødegård',
#   'father_name': 'Åsmund Ødegård'},
#  {'person_id': 41964,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Camilla',
#   'last_name': 'Stadven',
#   'display_name': 'Camilla Stadven',
#   'birthdate': '2007-08-10T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'camilla@stadven.no',
#   'cellphone': '+47 459 19 178',
#   'address_line_1': 'Sundbyveien 56',
#   'city': 'VINTERBRO',
#   'postal_code': '1407',
#   'mother_name': 'Eva Irene Stadven',
#   'father_name': 'Morten Stadven'},
#  {'person_id': 41996,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Cornelia',
#   'last_name': 'Olsen',
#   'display_name': 'Cornelia Olsen',
#   'birthdate': '2007-09-01T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'cornhaukols@gmail.com',
#   'cellphone': '+47 902 68 384',
#   'address_line_1': 'Nordengveien 6',
#   'city': 'Vinterbro',
#   'postal_code': '1407',
#   'mother_name': 'Else Marit Olsen',
#   'father_name': 'Kåre Olsen'},
#  {'person_id': 42645,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Anna Lene',
#   'last_name': 'Boek',
#   'display_name': 'Anna Lene Boek',
#   'birthdate': '2007-07-04T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'leneboek@gmail.com',
#   'cellphone': '+47 950 18 873',
#   'address_line_1': 'Kroerveien 640',
#   'city': 'ÅS',
#   'postal_code': '1435',
#   'mother_name': 'Jeanette Boek - de Boer',
#   'father_name': 'Albert Boek'},
#  {'person_id': 41618,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Ariana',
#   'last_name': 'Øyen-Havekes',
#   'display_name': 'Ariana Øyen-Havekes',
#   'birthdate': '2007-04-28T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'arianaoyen07@gmail.com',
#   'cellphone': '+47 955 25 918',
#   'address_line_1': 'Liaveien 35',
#   'city': 'ÅS',
#   'postal_code': '1435',
#   'mother_name': 'Ingrid Øyen-Havekes',
#   'father_name': 'Peter Øyen-Havekes'}]

# %%
from api_complete_documentation import * 
SUPABASE_URL = "https://qvkdyodpfauvpsamrmew.supabase.co"
SUPABASE_ANON_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InF2a2R5b2RwZmF1dnBzYW1ybWV3Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDkzNzMyMDEsImV4cCI6MjA2NDk0OTIwMX0.gMscCXj733-_cT87_ErXPHaaa3YQdWE5gjpJ8XZ4yXI"
API_KEY="cf364efb26fca32391f4190bf077bdb2"
client = create_client(SUPABASE_URL, SUPABASE_ANON_KEY)

# %%
import logging
logger = logging.getLogger(__name__)

def get_current_season(self)-> str:
        year, month = datetime.now().year, datetime.now().month
        if month < 8:
            year = str(year).replace("20","")
            return f'{int(year)-1}/{year}'
        else:
            return f'{year}/{int(year)+1}'
def parse_role(birth_year : int, season : str = None, ) -> str:
    if not season:
        logger.info("No season selected. Choosing current season as default")
        season = get_current_season()
    elif not isinstance(season,str): 
        logger.warning(f"Season {season} excepted to be type 'str', but are {type(season)}. Selecting current season as default")
        season = get_current_season()
    elif len(season.split("/")) != 2:
        logger.warning("Season expected to have format 'year1/year2. Selecting current season as default")
        season = get_current_season()
    
    year = int(f'20{season.split("/")[1]}')
    print(f'YEAR: {year} with type {type(year)}, BIRTH_YEAR: {birth_year} with type {type(birth_year)}')
    diff = year - birth_year
    if diff <= 16 and diff >= 14:
        return "genf"
    elif diff <= 18 and diff >= 17:
        return "hjelpementor"
    elif diff < 14:
        return None
    else:
        return "mentor"


def apply_role(birth_date : str | date | datetime, season = None):
    if isinstance(birth_date, str):
        try:
            birth_date = datetime.strptime(birth_date, "%Y-%m-%d").date()
        except ValueError as e:
            logger.error(f"Error parsing birth_date string {birth_date}: {e}")
            return "unknown"
    
    try:
        birth_year = birth_date.year
        return parse_role(birth_year, season)
    except Exception as e:
        logger.error(f"Error applying role for birth_date {birth_date}: {e}")
        return "unknown"

bc_m = fetch_profiles(client, API_KEY)
bc_m = pd.DataFrame(bc_m)
bc_m = bc_m.loc[bc_m["role"] != "parent", :].drop(columns = ["role"]).copy()
df_bc = fetch_job_logs(client, API_KEY, date(2026,1,1), date(2026,12,31))
df_bc = pd.DataFrame(df_bc)
df_bc["season"] = "25/26"
bc_m["role"] = bc_m["date_of_birth"].apply(lambda x: apply_role(x, season="25/26"))
df = pd.merge(df_bc, bc_m.loc[:,['id','email',"bank_account_number","role"]], left_on='worker_id', right_on='id', how='left')
to_keep = ["worker_id",
            #"cost",
        "hours_worked",
        "worker_first_name",
        "worker_last_name",
        "date_completed",
        "work_type",
        "email",
        "bank_account_number",
        "role","season",
        "units_completed",
        #"hourly_rate",
        "comments",
        ]
df = df.loc[:,to_keep].copy()
# Out:
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# Error applying role for birth_date None: 'NoneType' object has no attribute 'year'
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2003 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2005 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1996 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1999 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1998 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2026 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1998 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2000 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1998 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1999 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1998 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1998 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2006 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1999 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1989 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1993 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2000 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2003 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2006 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1999 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2000 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2001 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2003 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2002 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2003 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2001 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1999 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1982 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1999 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2001 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2001 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2001 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2004 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1998 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2000 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1981 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2001 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1991 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1993 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2003 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 1995 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2007 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2007 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2006 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2026 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2007 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2008 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2009 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2010 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2011 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2012 with type <class 'int'>
# YEAR: 2026 with type <class 'int'>, BIRTH_YEAR: 2000 with type <class 'int'>

# %%
import numpy as np
df.replace([np.nan,"nan", "None", pd.NaT, pd.NA], None, inplace = True)
data = df[:10].to_dict(orient = "records")
data
# Out:
# [{'worker_id': '6e6fd625-2030-4228-8dda-f20f7715ed47',
#   'hours_worked': 4.5,
#   'worker_first_name': 'Leon',
#   'worker_last_name': 'Neümuller',
#   'date_completed': '2026-02-11',
#   'work_type': 'bccof_utomhus',
#   'email': 'leon.neumuller04@gmail.com',
#   'bank_account_number': '61851101313',
#   'role': 'hjelpementor',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None},
#  {'worker_id': '2ad15be4-d355-4d82-8168-a6a5338d909c',
#   'hours_worked': 0.25,
#   'worker_first_name': 'Theodor',
#   'worker_last_name': 'Schmidt',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'theodor.schmidt2012@gmail.com',
#   'bank_account_number': '9820 06 24122',
#   'role': 'genf',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': 'Registrerte 15 min for lite på forrige'},
#  {'worker_id': 'ca102e20-d03e-48ae-9b49-bc4734531f45',
#   'hours_worked': 0.5,
#   'worker_first_name': 'Mille Tomine',
#   'worker_last_name': 'Fuglset',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'millefuglz@gmail.com',
#   'bank_account_number': '60111812260',
#   'role': 'genf',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': 'Jeg vet ikke hvordan man sletter den andre men jeg jobbet hvertfall vask i 2 timer også sa de at vi egt bare registrere 1t og 30m men vi fikk 2t istede'},
#  {'worker_id': 'cff03a72-1567-482f-b2a3-7339612645cd',
#   'hours_worked': 2.0,
#   'worker_first_name': 'Michelle Helén',
#   'worker_last_name': 'Pfeifer',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'pfeifer.mhp@gmail.com',
#   'bank_account_number': '18131360750',
#   'role': 'mentor',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None},
#  {'worker_id': 'abf487f0-843a-4e4c-b644-2a52bd08b81e',
#   'hours_worked': 2.0,
#   'worker_first_name': 'Kevin',
#   'worker_last_name': 'Hud',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'kevinhud0505@gmail.com',
#   'bank_account_number': '12253454014',
#   'role': 'hjelpementor',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None},
#  {'worker_id': '32c9cb93-9ef1-4443-93d6-b09e2bda6eef',
#   'hours_worked': 0.5,
#   'worker_first_name': 'Helena',
#   'worker_last_name': 'Bekkevold',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'helena.bekk1@gmail.com',
#   'bank_account_number': '61851082696',
#   'role': 'mentor',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None},
#  {'worker_id': '07572961-5bc0-4a78-a97d-ce7fb543e57f',
#   'hours_worked': 2.0,
#   'worker_first_name': 'Isak',
#   'worker_last_name': 'Baumann',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'isak.baumann.11@gmail.com',
#   'bank_account_number': '12253192451',
#   'role': 'genf',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None},
#  {'worker_id': '71755b05-f310-4dd4-9c28-8f152fdd027d',
#   'hours_worked': 0.5,
#   'worker_first_name': 'Charlotte',
#   'worker_last_name': 'Schmidt',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'chasch.schmidt@gmail.com',
#   'bank_account_number': '37901933988',
#   'role': 'genf',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': 'Fikk registrere 2t allikavel isteden for 1,5'},
#  {'worker_id': '570fb64e-51b1-4267-b811-6b96a0a6a70d',
#   'hours_worked': 2.0,
#   'worker_first_name': 'Deborah',
#   'worker_last_name': 'Schmidt',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'debsch11@icloud.com',
#   'bank_account_number': '37901933961',
#   'role': 'genf',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None},
#  {'worker_id': 'feebeb6e-f0c1-4ce7-8250-b3d8b5b8f024',
#   'hours_worked': 2.0,
#   'worker_first_name': 'Michelle',
#   'worker_last_name': 'Bårdsen',
#   'date_completed': '2026-02-09',
#   'work_type': 'bccof_vask',
#   'email': 'michellebardsen@gmail.com',
#   'bank_account_number': '62421140273',
#   'role': 'mentor',
#   'season': '25/26',
#   'units_completed': None,
#   'comments': None}]
