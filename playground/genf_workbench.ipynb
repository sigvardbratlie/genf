# %% [markdown]
# # Genf Workbench #

# %%
import re
from typing import Literal
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
import os
import logging
from google.cloud import bigquery
load_dotenv()
# Out:
# True

# %%
from supabase import create_client 
supabase = create_client(os.getenv("SUPABASE_URL"),os.getenv("SUPABASE_ANON_KEY"))

# %%
response = supabase.table("bcc_members").select("*").limit(10).execute()
response.data
# Out:
# [{'person_id': 42403,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Othilie Smith',
#   'last_name': 'Nielsen',
#   'display_name': 'Othilie Smith Nielsen',
#   'birthdate': '2007-04-05T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'othilienielsen@gmail.com',
#   'cellphone': '+47 47 62 60 15',
#   'address_line_1': 'Nilseskauveien 10',
#   'city': 'KRÅKSTAD',
#   'postal_code': '1408',
#   'mother_name': 'Elisabeth Smith Nielsen',
#   'father_name': 'Johan Riis Nielsen'},
#  {'person_id': 41647,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Michelle',
#   'last_name': 'Pfeifer',
#   'display_name': 'Michelle Helen Pfeifer',
#   'birthdate': '2007-04-23T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'pfeifer.mhp@gmail.com',
#   'cellphone': '+47 472 40 800',
#   'address_line_1': 'Glenneveien 4',
#   'city': 'KRÅKSTAD',
#   'postal_code': '1408',
#   'mother_name': 'Esther Pfeifer',
#   'father_name': 'Sigurd Pfeifer'},
#  {'person_id': 41629,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Eunike',
#   'last_name': 'Skare',
#   'display_name': 'Eunike Skare',
#   'birthdate': '2007-03-14T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'eunike.skare@gmail.com',
#   'cellphone': '+47 483 06 257',
#   'address_line_1': 'Solbakkveien 13',
#   'city': 'LANGHUS',
#   'postal_code': '1405',
#   'mother_name': 'Rebekka Steigmüller Skare',
#   'father_name': 'Per Sveinung Skare'},
#  {'person_id': 41617,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Ida Lin',
#   'last_name': 'Baumann',
#   'display_name': 'Ida Lin Baumann',
#   'birthdate': '2007-04-19T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'idalinbaum@icloud.com',
#   'cellphone': '+47 969 18 919',
#   'address_line_1': 'Berger Terrasse 10',
#   'city': 'NORDRE FROGN',
#   'postal_code': '1455',
#   'mother_name': 'Heidi Drageseth Baumann',
#   'father_name': 'Olav Baumann'},
#  {'person_id': 42250,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Savannah',
#   'last_name': 'Schmidt',
#   'display_name': 'Savannah Schmidt',
#   'birthdate': '2007-11-25T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'savannah.schmidt@icloud.com',
#   'cellphone': '+47 48 40 85 23',
#   'address_line_1': 'Gamle Kongevei 18',
#   'city': 'SKI',
#   'postal_code': '1423',
#   'mother_name': 'Silje Drageseth Schmidt',
#   'father_name': 'Ron Schmidt'},
#  {'person_id': 42053,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Elisabeth',
#   'last_name': 'Ødegård',
#   'display_name': 'Elisabeth Ødegård',
#   'birthdate': '2007-10-08T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'elisabethodegard001@gmail.com',
#   'cellphone': '+47 923 56 711',
#   'address_line_1': 'Sneisveien 26',
#   'city': 'VINTERBRO',
#   'postal_code': '1407',
#   'mother_name': 'Anita Ødegård',
#   'father_name': 'Åsmund Ødegård'},
#  {'person_id': 41964,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Camilla',
#   'last_name': 'Stadven',
#   'display_name': 'Camilla Stadven',
#   'birthdate': '2007-08-10T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'camilla@stadven.no',
#   'cellphone': '+47 459 19 178',
#   'address_line_1': 'Sundbyveien 56',
#   'city': 'VINTERBRO',
#   'postal_code': '1407',
#   'mother_name': 'Eva Irene Stadven',
#   'father_name': 'Morten Stadven'},
#  {'person_id': 41996,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Cornelia',
#   'last_name': 'Olsen',
#   'display_name': 'Cornelia Olsen',
#   'birthdate': '2007-09-01T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'cornhaukols@gmail.com',
#   'cellphone': '+47 902 68 384',
#   'address_line_1': 'Nordengveien 6',
#   'city': 'Vinterbro',
#   'postal_code': '1407',
#   'mother_name': 'Else Marit Olsen',
#   'father_name': 'Kåre Olsen'},
#  {'person_id': 42645,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Anna Lene',
#   'last_name': 'Boek',
#   'display_name': 'Anna Lene Boek',
#   'birthdate': '2007-07-04T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'leneboek@gmail.com',
#   'cellphone': '+47 950 18 873',
#   'address_line_1': 'Kroerveien 640',
#   'city': 'ÅS',
#   'postal_code': '1435',
#   'mother_name': 'Jeanette Boek - de Boer',
#   'father_name': 'Albert Boek'},
#  {'person_id': 41618,
#   'created_at': '2026-02-04T07:56:35.550713+00:00',
#   'first_name': 'Ariana',
#   'last_name': 'Øyen-Havekes',
#   'display_name': 'Ariana Øyen-Havekes',
#   'birthdate': '2007-04-28T00:00:00+00:00',
#   'gender': 'Female',
#   'email': 'arianaoyen07@gmail.com',
#   'cellphone': '+47 955 25 918',
#   'address_line_1': 'Liaveien 35',
#   'city': 'ÅS',
#   'postal_code': '1435',
#   'mother_name': 'Ingrid Øyen-Havekes',
#   'father_name': 'Peter Øyen-Havekes'}]

# %%
from api_complete_documentation import * 
SUPABASE_URL = "https://qvkdyodpfauvpsamrmew.supabase.co"
SUPABASE_ANON_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InF2a2R5b2RwZmF1dnBzYW1ybWV3Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDkzNzMyMDEsImV4cCI6MjA2NDk0OTIwMX0.gMscCXj733-_cT87_ErXPHaaa3YQdWE5gjpJ8XZ4yXI"
API_KEY="cf364efb26fca32391f4190bf077bdb2"
client = create_client(SUPABASE_URL, SUPABASE_ANON_KEY)

# %%
data = fetch_profiles(client, API_KEY)

# %%
n = []
for item in data:
    if item["role"] != "parent":
        n.append(item)

n[:10]
# Out:
# [{'id': 'd62a2e53-66b1-47b0-84b5-5873f8eab987',
#   'first_name': 'Richard',
#   'last_name': 'Stadven',
#   'phone': None,
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-02-06T10:35:23.612454+00:00',
#   'updated_at': '2026-02-06T10:35:23.612454+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': None,
#   'age_category': 'Unknown',
#   'bank_account_number': None,
#   'custom_id': None,
#   'email': 'richard@dalenvvs.no'},
#  {'id': 'bbdb828f-c76f-4c4e-b08b-b94d8810226a',
#   'first_name': 'Emma Chantel',
#   'last_name': 'Bjørgengen',
#   'phone': None,
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-02-04T18:03:42.671456+00:00',
#   'updated_at': '2026-02-04T18:03:42.671456+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': None,
#   'age_category': 'Unknown',
#   'bank_account_number': None,
#   'custom_id': None,
#   'email': 'emma.chantel05@icloud.com'},
#  {'id': '4c707c78-aa5e-4692-b867-e415142afac5',
#   'first_name': 'Marlin',
#   'last_name': 'Schytt',
#   'phone': None,
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-02-04T07:46:49.748361+00:00',
#   'updated_at': '2026-02-04T07:46:49.748361+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': None,
#   'age_category': 'Unknown',
#   'bank_account_number': None,
#   'custom_id': None,
#   'email': 'marschyx5@gmail.com'},
#  {'id': 'bce7a0f0-3064-4e28-a1bb-2edf81556dcf',
#   'first_name': 'Ronny Stadven',
#   'last_name': 'Pedersen',
#   'phone': '45116531',
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-02-04T07:46:04.083737+00:00',
#   'updated_at': '2026-02-04T08:22:30.613108+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': '2003-01-05',
#   'age_category': 'O18',
#   'bank_account_number': '12073804017',
#   'custom_id': None,
#   'email': 'ronnypedersen65@yahoo.no'},
#  {'id': '3a929aee-457e-4ff9-a00b-b03392db1d04',
#   'first_name': 'Oscar',
#   'last_name': 'Landgraff Nilsen',
#   'phone': None,
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-02-03T18:03:07.58668+00:00',
#   'updated_at': '2026-02-03T18:03:07.58668+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': None,
#   'age_category': 'Unknown',
#   'bank_account_number': None,
#   'custom_id': None,
#   'email': 'landgraffnilsen@outlook.com'},
#  {'id': '22cbc9bf-9afb-405c-81ee-72f4b7e7c2f3',
#   'first_name': 'Mariann',
#   'last_name': 'Bjørgengen',
#   'phone': None,
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-01-27T14:22:34.003777+00:00',
#   'updated_at': '2026-01-27T14:22:34.003777+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': None,
#   'age_category': 'Unknown',
#   'bank_account_number': None,
#   'custom_id': None,
#   'email': 'mariann.bjorgengen@gmail.com'},
#  {'id': '85a263dc-ea84-4f26-8d4e-0564f2b00ec5',
#   'first_name': 'Selma Maria',
#   'last_name': 'Haukelidsæter',
#   'phone': '46505514',
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-01-24T16:59:59.008205+00:00',
#   'updated_at': '2026-02-06T10:49:22.625361+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': '2005-09-02',
#   'age_category': 'O18',
#   'bank_account_number': '6185.11.00112',
#   'custom_id': None,
#   'email': 'selmahauk@gmail.com'},
#  {'id': '3ccfe6d4-1175-4ede-a11f-73f311074946',
#   'first_name': 'Sigvard',
#   'last_name': 'Bratlie',
#   'phone': '93849732',
#   'role': 'admin',
#   'availability_notes': None,
#   'created_at': '2026-01-23T20:36:23.20242+00:00',
#   'updated_at': '2026-01-23T21:22:35.867635+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': '1996-03-14',
#   'age_category': 'O18',
#   'bank_account_number': '18225733577',
#   'custom_id': None,
#   'email': 'sigvard@sibr.no'},
#  {'id': '735b1479-680b-4148-97c9-dc5608cafa8f',
#   'first_name': 'Alvilde',
#   'last_name': 'Olstad',
#   'phone': '94087968',
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-01-23T18:57:43.943824+00:00',
#   'updated_at': '2026-02-03T18:01:47.118075+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': '2010-10-27',
#   'age_category': 'U16',
#   'bank_account_number': '61851100570',
#   'custom_id': 45499,
#   'email': 'alvildeolstad@gmail.com'},
#  {'id': '24ce6078-c499-4903-b6ce-0988a38810e6',
#   'first_name': 'Emma Viola',
#   'last_name': 'Lindstad',
#   'phone': '+4748915825',
#   'role': 'member',
#   'availability_notes': None,
#   'created_at': '2026-01-20T16:09:10.329159+00:00',
#   'updated_at': '2026-02-03T07:12:16.687978+00:00',
#   'organization_id': 'fdcd8195-39ba-4fae-a4dd-1b664b3a01f1',
#   'monthly_goal': 10,
#   'date_of_birth': '2012-05-24',
#   'age_category': 'U16',
#   'bank_account_number': '1226.13.30847',
#   'custom_id': 46874,
#   'email': 'emmavlindstad@gmail.com'}]
