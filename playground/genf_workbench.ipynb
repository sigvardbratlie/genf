# %% [markdown]
# # Genf Workbench #

# %%
# Out:
# '/Users/sigvardbratlie/Documents/Projects/genf/playground'

# %%
from src.GENF import GENF
import re
from typing import Literal
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
import os
import logging
load_dotenv()
os.getcwd(), os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
# Out:
# ('/Users/sigvardbratlie/Documents/Projects/genf/playground',
#  'config/genf-446213-da3d943bbef2.json')

# %%
logger = logging.getLogger(__name__)
genf = GENF(logger=logger)
# Out:
# 2025-12-04 14:45:14,601 - GENF - INFO - Cloud Logging is disabled. Using local logging to /Users/sigvardbratlie/Documents/Projects/genf/logfiles/GENF.log.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 logger = Logger('GENF')
# ----> 2 bq = BigQuery(logger = logger)
#       3 genf = GENF(logger=logger, bigquery_module=bq)
#
# File ~/Documents/Projects/genf/.venv/lib/python3.13/site-packages/sibr_module/bigquery.py:47, in BigQuery.__init__(self, project_id, logger, dataset)
#      45 if project_id is None:
#      46     cred_path = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
# ---> 47     with open(cred_path,"r") as f:
#      48         cred = json.load(f)
#      49         project_id = cred.get("project_id")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config/genf-446213-da3d943bbef2.json'

# %%
df = genf.get_all_timer()
# Out:
# /Users/sigvardbratlie/Documents/Projects/genf/GENF.py:278: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["f_dato"] = pd.to_datetime(df["f_dato"], errors='coerce', dayfirst=False)

# %%
df["dato"].min(), df["dato"].max(), len(df)
# Out:
# (Timestamp('2025-08-08 00:00:00'), Timestamp('2025-11-29 00:00:00'), 1006)

# %%
bq.to_bq(df, table_name = "timer_25_26",dataset_name = "genf", if_exists="replace")
# Out:
# 2025-12-03 13:38:18,396 - GENF - INFO - DataFrame cleaned and prepared for BigQuery upload.
# 2025-12-03 13:38:23,463 - GENF - INFO - 1006 rader lagret i genf-446213.genf.timer_25_26

# %%
df_ = pd.read_csv("/Users/sigvardbratlie/Downloads/settlements-2025-07-15-2025-09-13.csv")

# %%
df = df_.loc[df_["Type"].isin(["Capture","Refund"]),["Booking date","Amount","Customer name","Message","Open Amount category"]]

# %%
genser = 365
oppstartsfest = 100
lunsj = 500

# %%
df["Amount"].sum()
# Out:
# np.float64(18240.0)

# %%
s = 100
df.loc[(df["Amount"]==s) & (df["Amount"]<s*2),"Amount"].sum()
# Out:
# np.float64(6400.0)

# %%
s = 365
df.loc[(df["Amount"]==s) & (df["Amount"]<s*2),"Amount"].sum()
# Out:
# np.float64(5475.0)

# %%
sums = []
for s in [genser,oppstartsfest,lunsj]:
    sums.append(df.loc[(df["Amount"]==s) | (df["Amount"]==s*2) | (df["Amount"]==s*3),"Amount"].sum())

# %%
import numpy as np
np.array(sums).sum()
# Out:
# np.float64(17775.0)

# %%
pays = {}
for idx,n in enumerate(["genser","oppstartsfest","lunsj"]):
    pays[n] = int(sums[idx])

# %%
pays
# Out:
# {'genser': 5475, 'oppstartsfest': 6400, 'lunsj': 1500}

# %%
genser = df.loc[(df["Amount"]==365) | (df["Amount"]==-365) | (df["Amount"]==365*2+100), "Amount"].sum()
6935-genser
# Out:
# np.float64(995.0)

# %%
91*500
# Out:
# 45500

# %%
lunsj = df.loc[(df["Amount"]==500) | (df["Amount"]==500*2), "Amount"].sum()
lunsj
# Out:
# np.float64(3500.0)

# %%
oppstartsfest = df.loc[(df["Amount"]==100) | (df["Amount"]==100*2), "Amount"].sum()
oppstartsfest
# Out:
# np.float64(8800.0)

# %%
s = np.float64(5940.0)+np.float64(3500.0)+np.float64(8800.0)
s
# Out:
# np.float64(18240.0)

# %%
import json
with open("config/genf-446213-da3d943bbef2.json","r") as f:
    cont = json.load(f)
cont
# Out:
# {'type': 'service_account',
#  'project_id': 'genf-446213',
#  'private_key_id': 'da3d943bbef21f4920990f825f15b351686887ac',
# ...

# %%
import toml
with open(".streamlit/secrets.toml","w") as f:
    toml.dump(cont,f)

# %%
from datetime import datetime,timedelta
import calendar

# %%
year = 2025
month = 8
calendar.monthrange(year, month)[1]
# Out:
# 31

# %%
(datetime(year, month, 11) - datetime.today())
# Out:
# datetime.timedelta(days=-115, seconds=28620, microseconds=880906)

# %%
type()
# Out:
# NoneType

# %%
[].append(5)

# %%
int("Hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int("Hello")
#
# ValueError: invalid literal for int() with base 10: 'Hello'
